# %%
import numpy as np
import cv2
import random
from matplotlib import pyplot as plt
import albumentations as A
import glob

# %%
def blur(image):
    transform = A.Blur(blur_limit=30, always_apply=True)
    augmented_image = transform(image=image)['image']
    return augmented_image

def pixelize(image):
    transform = A.Downscale(scale_min=0.25, scale_max=0.35, interpolation=None, always_apply=True, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

def change_bc(image):
    transform = A.RandomBrightnessContrast(brightness_limit=[0, 0.6], contrast_limit=0.3, brightness_by_max=False, always_apply=True, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

def noize(image):
    transform = A.RandomRain (slant_lower=-10, slant_upper=10, drop_length=20, drop_width=1, drop_color=(200, 200, 200), blur_value=7, brightness_coefficient=1, rain_type='drizzle', always_apply=True, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

# %%
result = random.choice(list_of_functions)(image)

# %%
def visualize(image):
    plt.figure(figsize=(10, 10))
    plt.axis('off')
    plt.imshow(image)

# %%
image = cv2.imread('/home/nikitavas/plannerix/Augmentation/initial_image.jpeg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
list_of_functions = [blur, pixelize, change_bc, noize]

# %%
result = random.choice(list_of_functions)(image)

# %%
for i in range(80):
    random
    result = random.choice(list_of_functions)(image)
    image_name = f'/home/nikitavas/plannerix/Augmentation/augmented_images/_{i}_.png'
    cv2.imwrite(image_name, result)
# Out:
# /home/nikitavas/miniconda3/envs/mmdet/lib/python3.8/site-packages/albumentations/augmentations/transforms.py:1554: UserWarning: Using default interpolation INTER_NEAREST, which is sub-optimal.Please specify interpolation mode for downscale and upscale explicitly.For additional information see this PR https://github.com/albumentations-team/albumentations/pull/584
#   warnings.warn(

# %%
visualize(result)

# %%
def blur(image):
    transform = A.Blur(blur_limit=30, always_apply=True)
    augmented_image = transform(image=image)['image']
    return augmented_image

# %%
def pixelize(image):
    transform = A.Downscale(scale_min=0.25, scale_max=0.35, interpolation=None, always_apply=True, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

# %%
def change_bc(image):
    transform = A.RandomBrightnessContrast(brightness_limit=[0, 0.6], contrast_limit=0.3, brightness_by_max=False, always_apply=True, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

# %%
def noize(image):
    transform = A.RandomRain (slant_lower=-10, slant_upper=10, drop_length=20, drop_width=1, drop_color=(200, 200, 200), blur_value=7, brightness_coefficient=1, rain_type='drizzle', always_apply=False, p=0.5)
    augmented_image = transform(image=image)['image']
    return augmented_image

# %%
transform = A.RandomSunFlare (flare_roi=(0, 0, 1, 0.5), angle_lower=0, angle_upper=1, num_flare_circles_lower=1, num_flare_circles_upper=2, src_radius=100, src_color=(255, 255, 255), always_apply=True, p=0.5)
random.seed(8)
augmented_image = transform(image=image)['image']
visualize(augmented_image)

# %%
image2 = cv2.imread('/home/nikitavas/plannerix/Augmentation/initial_image.jpeg')
tmp = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY)

list_of_textures = []

for filepath in glob.glob('/home/nikitavas/plannerix/Augmentation/textures/*.jpeg'):
    print(filepath)
    list_of_textures.append(cv2.imread(filepath))

image3 = cv2.imread('/home/nikitavas/plannerix/Augmentation/texture_3.jpeg')
# Out:
# /home/nikitavas/plannerix/Augmentation/textures/texture_7.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_0.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_5.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_10.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_4.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_8.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_6.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_1.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_3.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_2.jpeg
# /home/nikitavas/plannerix/Augmentation/textures/texture_9.jpeg

# %%
tmp = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[222], line 1
# ----> 1 tmp = cv2.cvtColor(src, cv2.COLOR_BGR2GRAY)
#
# NameError: name 'src' is not defined

# %%
image3 = cv2.resize(image3, (image2.shape[1], image2.shape[0]))
visualize(image3)

# %%
def bg_change(image, list_of_textures):
    texture = random.choice(list_of_textures)
    angle = random.choice([0, 1, 2, 3])
    for _ in range(angle):
        texture = cv2.rotate(texture, cv2.ROTATE_90_CLOCKWISE)
    texture = cv2.resize(texture, (image.shape[1], image.shape[0]))

    tmp = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, alpha = cv2.threshold(tmp, 240, 255, cv2.THRESH_BINARY)
    
    image_new_bg = cv2.bitwise_and(texture, image2, mask=alpha)
    visualize(image_new_bg)

# %%
bg_change(image2, list_of_textures)

# %%
_, alpha = cv2.threshold(tmp, 240, 255, cv2.THRESH_BINARY)
visualize(cv2.bitwise_and(image3, image2, mask=alpha))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[298], line 2
#       1 _, alpha = cv2.threshold(tmp, 240, 255, cv2.THRESH_BINARY)
# ----> 2 visualize(cv2.bitwise_and(image3, image2, mask=alpha))
#
# error: OpenCV(4.7.0) /io/opencv/modules/core/src/arithm.cpp:212: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'binary_op'

# %%
visualize(cv2.bitwise_not(image))
